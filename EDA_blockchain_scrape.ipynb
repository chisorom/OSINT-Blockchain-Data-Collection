# %% [markdown]
# # Finding Patterns and Trends in Cleaned Data

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\chiso\Downloads\MYSQL\block_scraped_cleaned.csv")

# %%
df
# Out:
#                                     Name        Date created  \
# 0                                Bitcoin     January 3, 2009
# 1                               Litecoin         Oct 8, 2011
# 2                               Peercoin        Aug 19, 2012
# 3                              Primecoin         Jul 7, 2013
# 4                               MazaCoin                2014
# 5                               Namecoin           Not known
# 6                               Ethereum        Jul 30, 2015
# 7                               Arbitrum           Not known
# 8                                   Base       June 15, 2023
# 9                               Optimism           Not known
# 10                              StarkNet           Not known
# 11                         Polygon zkEVM           Not known
# 12                      Ethereum Classic        Jul 20, 2016
# 13                          Bitcoin Cash         Aug 1, 2017
# ...

# %%
#NaN values persist. Remove again and save
df.fillna('unknown', inplace= True)

# %%
df
# Out:
#                                     Name        Date created  \
# 0                                Bitcoin     January 3, 2009
# 1                               Litecoin         Oct 8, 2011
# 2                               Peercoin        Aug 19, 2012
# 3                              Primecoin         Jul 7, 2013
# 4                               MazaCoin                2014
# 5                               Namecoin           Not known
# 6                               Ethereum        Jul 30, 2015
# 7                               Arbitrum           Not known
# 8                                   Base       June 15, 2023
# 9                               Optimism           Not known
# 10                              StarkNet           Not known
# 11                         Polygon zkEVM           Not known
# 12                      Ethereum Classic        Jul 20, 2016
# 13                          Bitcoin Cash         Aug 1, 2017
# ...

# %%
#Get overall statistics of data
df.describe()
# Out:
#            Name Date created Created by Native cryptocurrency  \
# count        33           33         33                    33
# unique       33           27         24                    29
# top     Bitcoin    Not known    unknown                   ETH
# freq          1            7         10                     5
#
#        Consensus algorithm Programmable? Private  Permissioned? Finality  \
# count                   33            33       33            33       33
# unique                  13             7        4             4        7
# top                unknown           Yes       No       unknown  unknown
# freq                     7            14       16            20       22
#
#            Ledger state    Notes
# count                33       33
# unique                5       21
# top     Account balance  unknown
# freq                 11       11

# %%
#Let's look at only blockchains with UTXO model
df[df['Ledger state'].str.contains('UTXO')]
# Out:
#          Name        Date created  \
# 0     Bitcoin     January 3, 2009
# 1    Litecoin         Oct 8, 2011
# 2    Peercoin        Aug 19, 2012
# 3   Primecoin         Jul 7, 2013
# 4    MazaCoin                2014
# 5    Namecoin           Not known
# 14    Cardano        Sep 27, 2017
# 25  Avalanche  September 10, 2020
#
#                                            Created by Native cryptocurrency  \
# 0                                    Satoshi Nakamoto                   BTC
# 1                                         Charlie Lee                   LTC
# 2                                             unknown                   PPC
# 3                                          Sunny King                   XPM
# 4                        Payu Harris, AnonymousPirate                  MAZA
# 5                                             unknown                   NMC
# 14                  Charles Hoskinson and Jeremy Wood                   ADA
# ...

# %%
#Look at those with Account balance 
df[df['Ledger state'].str.contains('Account balance')]
# Out:
#                 Name   Date created                      Created by  \
# 7           Arbitrum      Not known                   Offchain Labs
# 8               Base  June 15, 2023                        Coinbase
# 9           Optimism      Not known                    Optimism PBC
# 10          StarkNet      Not known                       StarkWare
# 11     Polygon zkEVM      Not known              Polygon Technology
# 12  Ethereum Classic   Jul 20, 2016                         unknown
# 15              TRON   Jun 24, 2018                         unknown
# 16             Tezos   Jun 30, 2018   Arthur and  Kathleen Breitman
# 19            XinFin   June 1, 2019  XinFin Fintech, XDC Foundation
# 20          Algorand   Jun 10, 2019        Silvio Micali and others
# 21               $PC   Sep 16, 2019                         unknown
#
#    Native cryptocurrency Consensus algorithm  Programmable? Private   \
# 7                    ETH   Optimistic rollup            Yes  unknown
# ...

# %%
#We can also do the same when looking at L1's and L2's that use ETH

# %%
#Lastly, look at date created just to see which year has the most projects
df[df['Date created'].str.contains('2020')]
# Out:
#           Name        Date created  \
# 22      Solana      March 16, 2020
# 23       Oasis       June 18, 2020
# 24    Polkadot        May 26, 2020
# 25   Avalanche  September 10, 2020
# 26  MobileCoin         Dec 6, 2020
#
#                                            Created by Native cryptocurrency  \
# 22                    Anatoly Yakovenko and Raj Gokal                   SOL
# 23              Oasis Labs, Oasis Protocol Foundation                  ROSE
# 24                                Parity Technologies                   DOT
# 25  Emin Gün Sirer, Maofan "Ted" Yin and Kevin Sek...                  AVAX
# 26  MobileCoin Inc. (founded by Josh Goldbard and ...                   MOB
#
#                    Consensus algorithm        Programmable? Private   \
# 22     PoS with Proof of History (PoH)                  Yes       No
# 23                                 PoS   Yes (in ParaTimes)       No
# 24  Started with PoA then moved to PoS  Yes (in parachains)       No
# ...

# %%
print(df['Date created'].head())
# Out:
# 0    January 3, 2009
# 1        Oct 8, 2011
# 2       Aug 19, 2012
# 3        Jul 7, 2013
# 4               2014
# Name: Date created, dtype: object

# %%
#Find which year the most blockchains started
#df[df['Date created']].value_count()
#standardize years first. dtrip text before comma
df['Date created']= df['Date created'].str.strip().str.replace(r'^[^,]*, ', ' ', regex=True)

# %%
df
# Out:
#                                     Name Date created  \
# 0                                Bitcoin         2009
# 1                               Litecoin         2011
# 2                               Peercoin         2012
# 3                              Primecoin         2013
# 4                               MazaCoin         2014
# 5                               Namecoin    Not known
# 6                               Ethereum         2015
# 7                               Arbitrum    Not known
# 8                                   Base         2023
# 9                               Optimism    Not known
# 10                              StarkNet    Not known
# 11                         Polygon zkEVM    Not known
# 12                      Ethereum Classic         2016
# 13                          Bitcoin Cash         2017
# 14                               Cardano         2017
# 15                                  TRON         2018
# ...

# %%
#yes!
# Out:
# dtype('O')

# %%
df['Date created'].astype(str)
# Out:
# 0     2009-01-01
# 1     2011-01-01
# 2     2012-01-01
# 3     2013-01-01
# 4     2014-01-01
# 5            NaT
# 6     2015-01-01
# 7            NaT
# 8     2023-01-01
# 9            NaT
# 10           NaT
# 11           NaT
# 12    2016-01-01
# 13    2017-01-01
# 14    2017-01-01
# 15    2018-01-01
# 16    2018-01-01
# 17    2018-11-01
# 18    2018-01-01
# 19    2019-01-01
# 20    2019-01-01
# 21    2019-01-01
# 22    2020-01-01
# 23    2020-01-01
# 24    2020-01-01
# 25    2020-01-01
# 26    2020-01-01
# 27           NaT
# 28    2021-01-01
# 29           NaT
# 30    2022-01-01
# 31    2016-01-01
# 32    2017-01-01
# Name: Date created, dtype: object

# %%
df['Date created'] = pd.to_datetime(df['Date created'], errors='coerce')

# %%
df['Date created'].value_counta()
# Out:
# Timestamp('2023-01-01 00:00:00')
